# %%
import pickle

# %%
with open("subjects.pickle", "rb") as p:
    subj_dict = pickle.load(p)

# %%
subj_dict[29123]
# Out:
# {'graph': {'Precentral_L': {'Frontal_Sup_L': {'weight': 761.0},
#    'Frontal_Sup_R': {'weight': 2.0},
#    'Frontal_Sup_Orb_L': {'weight': 431.0},
#    'Frontal_Sup_Orb_R': {'weight': 1.0},
#    'Frontal_Mid_L': {'weight': 2374.0},
#    'Frontal_Mid_R': {'weight': 8.0},
#    'Frontal_Mid_Orb_L': {'weight': 114.0},
#    'Frontal_Inf_Oper_L': {'weight': 3936.0},
#    'Frontal_Inf_Oper_R': {'weight': 12.0},
#    'Frontal_Inf_Tri_L': {'weight': 793.0},
#    'Frontal_Inf_Tri_R': {'weight': 15.0},
#    'Frontal_Inf_Orb_L': {'weight': 57.0},
#    'Rolandic_Oper_L': {'weight': 113.0},
#    'Supp_Motor_Area_L': {'weight': 46.0},
#    'Supp_Motor_Area_R': {'weight': 1.0},
#    'Olfactory_L': {'weight': 392.0},
#    'Olfactory_R': {'weight': 76.0},
#    'Frontal_Sup_Medial_L': {'weight': 20.0},
#    'Frontal_Med_Orb_L': {'weight': 93.0},
#    'Frontal_Med_Orb_R': {'weight': 3.0},
#    'Rectus_L': {'weight': 135.0},
#    'Rectus_R': {'weight': 8.0},
#    'Insula_L': {'weight': 9887.0},
# ...
