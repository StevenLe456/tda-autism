# %%
import pickle

# %%
with open("subjects.pickle", "rb") as p:
    subj_dict = pickle.load(p)

# %%
subj_dict[29123]
# Out:
# {'graph': {1: {3: {'weight': 761.0},
#    4: {'weight': 2.0},
#    5: {'weight': 431.0},
#    6: {'weight': 1.0},
#    7: {'weight': 2374.0},
#    8: {'weight': 8.0},
#    9: {'weight': 114.0},
#    11: {'weight': 3936.0},
#    12: {'weight': 12.0},
#    13: {'weight': 793.0},
#    14: {'weight': 15.0},
#    15: {'weight': 57.0},
#    17: {'weight': 113.0},
#    19: {'weight': 46.0},
#    20: {'weight': 1.0},
#    21: {'weight': 392.0},
#    22: {'weight': 76.0},
#    23: {'weight': 20.0},
#    25: {'weight': 93.0},
#    26: {'weight': 3.0},
#    27: {'weight': 135.0},
#    28: {'weight': 8.0},
#    29: {'weight': 9887.0},
#    30: {'weight': 56.0},
#    31: {'weight': 278.0},
#    32: {'weight': 55.0},
#    33: {'weight': 1035.0},
#    34: {'weight': 10.0},
#    35: {'weight': 773.0},
#    36: {'weight': 89.0},
#    37: {'weight': 160.0},
#    38: {'weight': 7.0},
#    41: {'weight': 231.0},
#    42: {'weight': 2.0},
#    43: {'weight': 22.0},
#    45: {'weight': 193.0},
# ...
