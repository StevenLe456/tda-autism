# %%
# %matplotlib inline

# %%
import networkx as nx
import random as r

# %%
g = nx.read_weighted_edgelist("ABIDEII-connectomes/ABIDEII-BNI_1_Connectomes/HarvardOxfordcort-maxprob-thr25_space-MNI152NLin6_res-2x2x2/sub-29011_ses-1_connectome.csv", create_using=nx.DiGraph)

# %%
nx.draw_random(g, node_size=100, node_color=[(r.random(), r.random(), r.random()) for i in range(g.number_of_nodes())])

# %%
nx.to_dict_of_dicts(g)
# Out:
# {'1': {'2': {'weight': 9729.0},
#   '3': {'weight': 1314.0},
#   '4': {'weight': 2372.0},
#   '5': {'weight': 836.0},
#   '6': {'weight': 41.0},
#   '7': {'weight': 1159.0},
#   '8': {'weight': 11.0},
#   '17': {'weight': 651.0},
#   '18': {'weight': 34.0},
#   '19': {'weight': 76.0},
#   '20': {'weight': 8.0},
#   '21': {'weight': 6.0},
#   '22': {'weight': 11.0},
#   '25': {'weight': 1329.0},
#   '26': {'weight': 53.0},
#   '27': {'weight': 5471.0},
#   '28': {'weight': 1127.0},
#   '29': {'weight': 456.0},
#   '30': {'weight': 59.0},
#   '31': {'weight': 501.0},
#   '33': {'weight': 8540.0},
#   '34': {'weight': 8.0},
#   '37': {'weight': 8.0},
#   '41': {'weight': 1609.0},
#   '42': {'weight': 1334.0},
#   '43': {'weight': 14.0},
#   '44': {'weight': 1.0},
#   '45': {'weight': 242.0},
#   '46': {'weight': 148.0}},
#  '2': {'3': {'weight': 1787.0},
#   '4': {'weight': 2359.0},
#   '5': {'weight': 800.0},
#   '6': {'weight': 375.0},
#   '7': {'weight': 7464.0},
# ...
